# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
games = pd.read_csv('Clean/games_clean.csv')
players = pd.read_csv('Clean/players_clean.csv')
teams = pd.read_csv('Clean/teams_clean.csv')
ranking = pd.read_csv('Clean/ranking_clean.csv')
games_details = pd.read_csv('Clean/games_details_clean.csv')

# %%
ranking.head()
# Out:
#    Unnamed: 0     Team ID Conference         Team  Games  Wins  Losses  \
# 0           0  1610612762       West         Utah     72    52      20
# 1           1  1610612756       West      Phoenix     72    51      21
# 2           2  1610612743       West       Denver     72    47      25
# 3           3  1610612746       West  LA Clippers     72    47      25
# 4           4  1610612742       West       Dallas     72    42      30
#
#    Wins % Record Home Record Away
# 0   0.722        31-5       21-15
# 1   0.708        27-9       24-12
# 2   0.653       25-11       22-14
# 3   0.653       26-10       21-15
# 4   0.583       21-15       21-15

# %%
ranking.groupby('Team').Wins.sum().sort_values(ascending=False).plot.bar(figsize=(15,6))
plt.title = ("Winnings")
plt.xlabel("NBA Teams")
plt.ylabel("Points")
plt.show()

# %%
ranking.groupby('Team').Losses.sum().sort_values(ascending=False).plot.bar(figsize=(15,6), color='orange')
plt.xlabel("NBA Teams")
plt.ylabel("Points")
plt.show()

# %%
players_details_df = games_details.groupby(['Player ID']).sum("Points").sort_values("Points", ascending=False)

# %%
players_details_df.head()
# Out:
#            Unnamed: 0        Team ID  Field Goals Made  Field Goals Attempted  \
# Player ID
# 2544        523526106  2731599210748           16021.0                31910.0
# 2546        416250341  2317671745233           10928.0                24595.0
# 201142      397402433  1791001384268            9930.0                20234.0
# 2548        454667717  2201707625502           10256.0                21466.0
# 1717        432499188  2221034971218            9908.0                21014.0
#
#            Fiels Goals %  3 Pt Field Goals Made  3 Pt Field Goals Attempted  \
# Player ID
# 2544             829.292                 2453.0                      7136.0
# 2546             594.651                 1760.0                      5008.0
# 201142           541.771                 2056.0                      5408.0
# 2548             615.639                  688.0                      2289.0
# 1717             625.729                 1552.0                      4100.0
#
#            3 Pt Field Goals %  Free Throws Made  Free Throws Attempted  \
# Player ID
# 2544                  494.995            9629.0                13112.0
# 2546                  404.788            7030.0                 8636.0
# 201142                412.983            7245.0                 8241.0
# 2548                  223.833            6902.0                 9009.0
# 1717                  441.192            6559.0                 7376.0
#
#            Free Throws %  Rebounds  Assists  Personal Fouls   Points
# Player ID
# 2544            1179.730   12432.0  11925.0          3105.0  44124.0
# 2546            1009.752    8457.0   3735.0          3871.0  30646.0
# 201142           934.304    7646.0   4427.0          2153.0  29161.0
# 2548             924.819    6081.0   6809.0          2930.0  28102.0
# 1717            1047.120    9934.0   3213.0          2997.0  27927.0

# %%
games_and_player_merge = pd.merge(games_details, players, on="Player ID", how="inner")

# %%
games_and_player_merge_df = games_and_player_merge.groupby(['Player ID']).sum("Points").sort_values("Points", ascending=False)

# %%
games_and_player_merge_df

final_df = pd.DataFrame(games_and_player_merge, columns=["Player ID", "Player", "Points"])
final_df_groupby = final_df.groupby(['Player']).sum("Points").sort_values("Points", ascending=False)
print("The top five scorers")
final_df_groupby.head()
# Out:
# The top five scorers
#                   Player ID    Points
# Player
# LeBron James       47460864  485364.0
# Carmelo Anthony    43964328  367752.0
# Kevin Durant     2460368944  320771.0
# James Harden     2658272340  315384.0
# Dwyane Wade        38314276  309122.0
