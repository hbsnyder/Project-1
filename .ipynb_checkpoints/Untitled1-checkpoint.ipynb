# %%
import pandas as pd

# %%
ranking_csv = "Clean/ranking_clean.csv"
games_details_csv = "Clean/games_details_clean.csv"

# %%
ranking_df = pd.read_csv(ranking_csv)
games_details_df = pd.read_csv(games_details_csv)

# %%
games_details.head()
# Out:
#    Unnamed: 0     Team ID Team Abbr        City  Player ID Position   Minutes  \
# 0           0  1610612764       WAS  Washington     203078        F  34:36:00
# 1           1  1610612764       WAS  Washington    1629060        F  25:50:00
# 2           2  1610612764       WAS  Washington     203458        C     12:11
# 3           3  1610612764       WAS  Washington     203526        G     19:19
# 4           4  1610612764       WAS  Washington     201566        G  29:07:00
#
#    Field Goals Made  Field Goals Attempted  Field Goals %  \
# 0              14.0                   28.0          0.500
# 1               4.0                    6.0          0.667
# 2               3.0                    5.0          0.600
# 3               2.0                    5.0          0.400
# 4               2.0                   10.0          0.200
#
#    3 Pt Field Goals Made  3 Pt Field Goals Attempted  3 Pt Field Goals %  \
# ...

# %%
ranking.head()
# Out:
#    Unnamed: 0     Team ID Conference         Team  Games  Wins  Losses  \
# 0           0  1610612762       West         Utah     72    52      20
# 1           1  1610612756       West      Phoenix     72    51      21
# 2           2  1610612743       West       Denver     72    47      25
# 3           3  1610612746       West  LA Clippers     72    47      25
# 4           4  1610612742       West       Dallas     72    42      30
#
#    Wins % Record Home Record Away
# 0   0.722        31-5       21-15
# 1   0.708        27-9       24-12
# 2   0.653       25-11       22-14
# 3   0.653       26-10       21-15
# 4   0.583       21-15       21-15

# %%
ranking.groupby('Team').Wins.sum().sort_values(ascending=False).plot.bar(figsize=(15,6))
plt.title = ("Winnings")
plt.xlabel("NBA Teams")
plt.ylabel("Points")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-cd79bf71b881> in <module>
# ----> 1 details_df = pd.merge(ranking_df, games_details_df, on="Team ID")
#       2 details_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     714             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     715
# --> 716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
#     718         llabels, rlabels = _items_overlap_with_suffix(
#
# ...

# %%
details_df = pd.merge(ranking_df, games_details_df, on="Team ID")
details_df.head()
